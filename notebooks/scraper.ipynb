# %%
import os
import sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.scrap.scraper import CollectPortfolio

# %%
portfolio={
    'AAPL': 0.5,
    'TSLA' : 0.5
}

# %%
portfolio_collect=CollectPortfolio(portfolio, '../data/raw')

# %%
data=portfolio_collect.collect_portfolio_data(start_date='2024-01-01', end_date='2026-01-01', interval='1d')
# Out:
#                   AAPL        TSLA
# Date
# 2024-01-02  183.562195  248.419998
# 2024-01-03  182.187775  238.449997
# 2024-01-04  179.873932  237.929993
# 2024-01-05  179.152115  237.490005
# 2024-01-08  183.483063  240.449997
# ...                ...         ...
# 2025-12-24  273.302216  485.399994
# 2025-12-26  272.892975  475.190002
# 2025-12-29  273.252350  459.640015
# 2025-12-30  272.573578  454.429993
# 2025-12-31  271.355835  449.720001
#
# [502 rows x 2 columns]

# %%
data
# Out:
#                   AAPL        TSLA
# Date
# 2024-01-02  183.562195  248.419998
# 2024-01-03  182.187775  238.449997
# 2024-01-04  179.873932  237.929993
# 2024-01-05  179.152115  237.490005
# 2024-01-08  183.483063  240.449997
# ...                ...         ...
# 2025-12-24  273.302216  485.399994
# 2025-12-26  272.892975  475.190002
# 2025-12-29  273.252350  459.640015
# 2025-12-30  272.573578  454.429993
# 2025-12-31  271.355835  449.720001
#
# [502 rows x 2 columns]
