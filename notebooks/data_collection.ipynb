# %%
import os
import sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.data_collection.build_portfolio import build_portfolio_phase_one

# %%
portfolio={
    'AAPL': 0.10,
    'MSFT': 0.10,
    'NVDA': 0.10,
    'JPM':  0.10,
    'XOM':  0.10,
    'AMZN': 0.10,
    'META': 0.10,
    'GOOGL': 0.10,
    'TSLA': 0.10,
    'UNH':  0.10

}

# %%
portfolio_collect = build_portfolio_phase_one(
    portfolio_weights=portfolio,
    start_date="2016-01-01",
    end_date="2026-01-01",
    market_benchmark="SPY",
    output_filepath="../data/raw/portfolio_prices.csv"
)

# %%
print('======== Portfolio Weights ===========')
print(portfolio_collect['weights'])
# Out:
# ======== Portfolio Weights ===========
# AAPL     0.1
# MSFT     0.1
# NVDA     0.1
# JPM      0.1
# XOM      0.1
# AMZN     0.1
# META     0.1
# GOOGL    0.1
# TSLA     0.1
# UNH      0.1
# dtype: float64

# %%
print("=========== First 5 Rows of Portfolio Returns =========")
print(portfolio_collect["returns"].head())
# Out:
# =========== First 5 Rows of Portfolio Returns =========
#                 AAPL      MSFT      NVDA       JPM       XOM      AMZN  \
# Date
# 2016-01-05 -0.025059  0.004562  0.016064  0.001729  0.008521 -0.005024
# 2016-01-06 -0.019570 -0.018165 -0.041350 -0.014436 -0.008321 -0.001799
# 2016-01-07 -0.042205 -0.034783 -0.039645 -0.040439 -0.016006 -0.039058
# 2016-01-08  0.005287  0.003067 -0.021466 -0.022399 -0.020202 -0.001464
# 2016-01-11  0.016192 -0.000573  0.001688 -0.001528 -0.013389  0.017610
#
#                 META     GOOGL      TSLA       UNH
# Date
# 2016-01-05  0.004989  0.002752  0.000090  0.001890
# 2016-01-06  0.002336 -0.002889 -0.019648 -0.010199
# 2016-01-07 -0.049043 -0.024140 -0.015477 -0.029440
# 2016-01-08 -0.006025 -0.013617 -0.021563 -0.017218
# 2016-01-11  0.001849  0.002955 -0.014929 -0.005265

# %%
print("========= Market Benchmark Returns ============")
print(portfolio_collect["market_returns"].head())
# Out:
# ========= Market Benchmark Returns ============
#                  SPY
# Date
# 2016-01-05  0.001692
# 2016-01-06 -0.012614
# 2016-01-07 -0.023991
# 2016-01-08 -0.010976
# 2016-01-11  0.000990
